# %%
import pandas as pd

df1_1 = pd.read_csv('Jan_gps.csv')
df1_2 = pd.read_csv('Jan_transaction.csv')
df2 = pd.read_csv('Feb.csv')
df3 = pd.read_csv('Mar_m.csv')
# Out:
# C:\Users\xnin394\AppData\Local\Temp\ipykernel_9444\3058050908.py:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('Feb.csv')

# %%
df1 = pd.merge(df1_1, df1_2, on = 'transaction_id')

# %%
data_df = pd.concat([df1, df2, df3], ignore_index=True)
print(data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737926 entries, 0 to 737925
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   transaction_id                  737926 non-null  object
#  1   distance_from_home              737926 non-null  float64
#  2   distance_from_last_transaction  737926 non-null  float64
#  3   card_number                     737926 non-null  object
#  4   issue_year                      737926 non-null  int64
#  5   days_since_last_transaction     737926 non-null  int64
#  6   repeat_retailer                 737926 non-null  int64
#  7   used_chip                       737926 non-null  object
#  8   used_pin_number                 737792 non-null  float64
#  9   online_order                    737926 non-null  int64
#  10  single_transaction_mean         737926 non-null  float64
#  11  transaction_amount              737926 non-null  float64
# ...

# %%
pip install -U seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 绘制箱线图
plt.figure(figsize=(8, 6))
sns.boxplot(x='fraud', y='distance_from_home', data=data_df)
plt.title('Boxplot of Distance by Fraud (0, )')
plt.xlabel('Fraud')
plt.ylabel('Distance_from_home')
plt.show()

# 绘制小提琴图
plt.figure(figsize=(8, 6))
sns.violinplot(x='fraud', y='distance_from_home', data=data_df)
plt.title('Violinplot of Distance by Fraud (0, )')
plt.xlabel('Fraud')
plt.ylabel('Distance_from_home')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='fraud', y='distance_from_home', data=data_df)
plt.title('Boxplot of Distance by Fraud(0, 1000)')
plt.xlabel('Fraud')
plt.ylabel('Distance_from_home')
plt.ylim(0, 1000)
plt.show()

plt.figure(figsize=(8, 6))
sns.violinplot(x='fraud', y='distance_from_home', data=data_df)
plt.title('Violinplot of Distance by Fraud(0, 1000)')
plt.xlabel('Fraud')
plt.ylabel('Distance_from_home')
plt.ylim(0, 1000)
plt.show()

# %%
# 绘制柱状图
plt.figure(figsize=(8, 6))
sns.countplot(x='fraud', hue='online_order', data=data_df, palette='dark:blue')
plt.title('Bar Plot of Fraud by Online Order(0, )')
plt.xlabel('Fraud')
plt.ylabel('Count')
plt.show()

# %%
# 绘制箱线图
plt.figure(figsize=(8, 6))
sns.boxplot(x='fraud', y='transaction_amount', data=data_df)
plt.title('Boxplot of Transaction_amount by Fraud (0, )')
plt.xlabel('Fraud')
plt.ylabel('Transaction_amount')
plt.show()

# 绘制小提琴图
plt.figure(figsize=(8, 6))
sns.violinplot(x='fraud', y='transaction_amount', data=data_df)
plt.title('Violinplot of Transaction_amount by Fraud (0, )')
plt.xlabel('Fraud')
plt.ylabel('Transaction_amount')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='fraud', y='transaction_amount', data=data_df)
plt.title('Boxplot of Transaction_amount by Fraud(0, 20000)')
plt.xlabel('Fraud')
plt.ylabel('Transaction_amount')
plt.ylim(0, 20000)
plt.show()

plt.figure(figsize=(8, 6))
sns.violinplot(x='fraud', y='transaction_amount', data=data_df)
plt.title('Violinplot of Transaction_amount by Fraud(0, 6000)')
plt.xlabel('Fraud')
plt.ylabel('Transaction_amount')
plt.ylim(0, 6000)
plt.show()

# %%
## 3

# %%
## 3.1
data_df.drop(columns = ['transaction_id', 'card_number'], inplace = True)
print(data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737926 entries, 0 to 737925
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   distance_from_home              737926 non-null  float64
#  1   distance_from_last_transaction  737926 non-null  float64
#  2   issue_year                      737926 non-null  int64
#  3   days_since_last_transaction     737926 non-null  int64
#  4   repeat_retailer                 737926 non-null  int64
#  5   used_chip                       737926 non-null  object
#  6   used_pin_number                 737792 non-null  float64
#  7   online_order                    737926 non-null  int64
#  8   single_transaction_mean         737926 non-null  float64
#  9   transaction_amount              737926 non-null  float64
#  10  fraud                           737926 non-null  int64
# dtypes: float64(5), int64(5), object(1)
# ...

# %%
## 3.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 画直方图
plt.hist(data_df['distance_from_home'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel('Distance from Home')
plt.ylabel('Frequency')
plt.title('Distribution of Distance from Home(0, )')
plt.grid(True)
plt.show()
# 画直方图
plt.hist(data_df['distance_from_home'], range = (0, 100), bins=100, color='skyblue', edgecolor='black')
plt.xlabel('Distance from Home')
plt.ylabel('Frequency')
plt.title('Distribution of Distance from Home(0,100)')
plt.grid(True)
plt.show()

plt.hist(data_df['distance_from_home'], range = (9998, 11000), bins=100, color='skyblue', edgecolor='black')
plt.xlabel('Distance from Home')
plt.ylabel('Frequency')
plt.title('Distribution of Distance from Home(9998, 11000)')
plt.grid(True)
plt.show()

# %%
data_df['distance_from_home'].replace(9999, 2.0, inplace=True)
data_df = data_df[data_df['distance_from_home'] <= 10000]

# %%
from scipy.stats import chi2_contingency

cross_table = pd.crosstab(data_df['used_pin_number'], data_df['online_order'])
chi2, p, dof, expected = chi2_contingency(cross_table)
print('Chi Square Value:', chi2)
print('p-value:', p)
print(cross_table)
# Out:
# Chi Square Value: 75178.2415793383
# p-value: 0.0
# online_order          0       1
# used_pin_number
# 0.0              102566  578585
# 1.0               34978   21662

# %%
fill_values = data_df['online_order'].map({0:1, 1:0})
data_df['used_pin_number'] = data_df['used_pin_number'].fillna(fill_values)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737925 entries, 0 to 737925
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   distance_from_home              737925 non-null  float64
#  1   distance_from_last_transaction  737925 non-null  float64
#  2   issue_year                      737925 non-null  int64
#  3   days_since_last_transaction     737925 non-null  int64
#  4   repeat_retailer                 737925 non-null  int64
#  5   used_chip                       737925 non-null  object
#  6   used_pin_number                 737925 non-null  float64
#  7   online_order                    737925 non-null  int64
#  8   single_transaction_mean         737925 non-null  float64
#  9   transaction_amount              737925 non-null  float64
#  10  fraud                           737925 non-null  int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 67.6+ MB

# %%
##3.3
data_df['ratio_to_median_purchase_price'] = (data_df['transaction_amount'] / data_df['single_transaction_mean']).round(2)
print(data_df['ratio_to_median_purchase_price'].describe())
# Out:
# count    737925.000000
# mean          1.805176
# std           2.689030
# min           0.000000
# 25%           0.480000
# 50%           1.000000
# 75%           2.090000
# max         266.690000
# Name: ratio_to_median_purchase_price, dtype: float64

# %%
plt.hist(data_df['ratio_to_median_purchase_price'], bins=100, color='blue', edgecolor='black')
plt.xlabel('Ratio_to_median_purchase_price')
plt.ylabel('Frequency')
plt.title('Ratio to median purchase price (0, )')
# plt.grid(True)
plt.show()

# %%
## 3.4 HE BING

# %%
## 3.5
print(data_df['used_chip'].value_counts())
# Out:
# used_chip
# 0    436070
# 1    236319
# 0     42444
# 1     21351
# y      1660
# n        81
# Name: count, dtype: int64

# %%
data_df['used_chip'] = data_df['used_chip'].replace({'y':1, 'n':0, '1':1, '0':0})
print(data_df['used_chip'].value_counts())
# Out:
# used_chip
# 0    478595
# 1    259330
# Name: count, dtype: int64

# %%
## 4

# %%
## 4.1
plt.figure(figsize=(8, 6))
sns.countplot(x='fraud', hue='issue_year', data=data_df)
plt.title('Bar Plot of Fraud by Issue Year')
plt.xlabel('Fraud')
plt.ylabel('Count')
plt.show()

# %%
## 4.2

# %%
plt.hist(data_df['transaction_amount'], range = (0, 4000), bins=100, color='blue', edgecolor='black')
plt.xlabel('transaction_amount')
plt.ylabel('Frequency')
plt.title('Transaction_amount')
# plt.grid(True)
plt.show()

# %%
import numpy as np

data_df['transaction_amount_log'] = np.log(data_df['transaction_amount'])
plt.hist(data_df['transaction_amount_log'], bins=100, color='blue', edgecolor='black')
plt.xlabel('transaction_amount_log')
plt.ylabel('Frequency')
plt.title('Transaction_amount_log')
# plt.grid(True)
plt.show()

# %%
import pandas as pd

# 定义区间和对应的标签
bins = [-1, 50, float('inf')]
labels = [0, 1]

# 将 days_since_last_transaction 列分成四个区间，并转换为序数型变量
data_df['days_since_last_transaction_category'] = pd.cut(data_df['days_since_last_transaction'], bins=bins, labels=labels)

# 将序数型变量转换为整数型
data_df['days_since_last_transaction_category'] = pd.factorize(data_df['days_since_last_transaction_category'])[0] + 1

print(data_df['days_since_last_transaction_category'].value_counts())
# Out:
# days_since_last_transaction_category
# 1    724249
# 2     13676
# Name: count, dtype: int64

# %%
# 定义区间和对应的标签
bins = [0, 30, 90, 150, float('inf')]
labels = [1, 2, 3, 4]

# 将 days_since_last_transaction 列分成四个区间，并转换为序数型变量
data_df['distance_from_home_category'] = pd.cut(data_df['distance_from_home'], bins=bins, labels=labels)

# 将序数型变量转换为整数型
data_df['distance_from_home_category'] = pd.factorize(data_df['distance_from_home_category'])[0] + 1

print(data_df['distance_from_home_category'].value_counts())
# Out:
# distance_from_home_category
# 1    581689
# 2    117669
# 4     19996
# 3     18571
# Name: count, dtype: int64

# %%
# 计算所有变量之间的相关性
data_2 = data_df
correlation_matrix = data_2.corr()

# 使用热图表示相关性
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
print(data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737925 entries, 0 to 737925
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   distance_from_home                    737925 non-null  float64
#  1   distance_from_last_transaction        737925 non-null  float64
#  2   issue_year                            737925 non-null  int64
#  3   days_since_last_transaction           737925 non-null  int64
#  4   repeat_retailer                       737925 non-null  int64
#  5   used_chip                             737925 non-null  int64
#  6   used_pin_number                       737925 non-null  float64
#  7   online_order                          737925 non-null  int64
#  8   single_transaction_mean               737925 non-null  float64
#  9   transaction_amount                    737925 non-null  float64
# ...

# %%
selected_variables = ['distance_from_home', 'distance_from_last_transaction', 'online_order', 'transaction_amount',  
                      'ratio_to_median_purchase_price', 'days_since_last_transaction_category', 'fraud']
data_df_rdc = data_df[selected_variables]
print(data_df_rdc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737925 entries, 0 to 737925
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   distance_from_home                    737925 non-null  float64
#  1   distance_from_last_transaction        737925 non-null  float64
#  2   online_order                          737925 non-null  int64
#  3   transaction_amount                    737925 non-null  float64
#  4   ratio_to_median_purchase_price        737925 non-null  float64
#  5   days_since_last_transaction_category  737925 non-null  int64
#  6   fraud                                 737925 non-null  int64
# dtypes: float64(4), int64(3)
# memory usage: 45.0 MB
# None

# %%
# 计算所有变量之间的相关性
data_2 = data_df_rdc
correlation_matrix = data_2.corr()

# 使用热图表示相关性
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
## 4.1.2
value_count_fraud = data_df_rdc['fraud'].value_counts()
print(value_count_fraud)
# Out:
# fraud
# 0    660031
# 1     77894
# Name: count, dtype: int64

# %%
data_df_fraud_0 = data_df_rdc[data_df_rdc['fraud'] == 0]
data_df_fraud_1 = data_df_rdc[data_df_rdc['fraud'] == 1]
fraud_0_sampled = data_df_fraud_0.sample(n = 90000, random_state= 9)

sample_df = pd.concat([data_df_fraud_1, fraud_0_sampled])
print(sample_df['fraud'].value_counts())
# Out:
# fraud
# 0    90000
# 1    77894
# Name: count, dtype: int64

# %%
############################################
data = sample_df
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167894 entries, 3 to 178341
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   distance_from_home                    167894 non-null  float64
#  1   distance_from_last_transaction        167894 non-null  float64
#  2   online_order                          167894 non-null  int64
#  3   transaction_amount                    167894 non-null  float64
#  4   ratio_to_median_purchase_price        167894 non-null  float64
#  5   days_since_last_transaction_category  167894 non-null  int64
#  6   fraud                                 167894 non-null  int64
# dtypes: float64(4), int64(3)
# memory usage: 10.2 MB
# None

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# 假设 X 是特征矩阵，y 是目标向量
X = data[['distance_from_home', 'distance_from_last_transaction', 'online_order', 
         'transaction_amount', 'ratio_to_median_purchase_price', 'days_since_last_transaction_category']]
y = data['fraud']

# X 是你的特征，y 是你的目标变量（二分类）

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=19)

# 创建逻辑回归模型
model = LogisticRegression(max_iter = 130, solver = 'lbfgs')

# 训练模型
model.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = model.predict(X_test)

# 计算模型的准确率
accuracy = accuracy_score(y_test, y_pred)
print("模型准确率:", accuracy)

# 打印分类报告
print("分类报告:")
print(classification_report(y_test, y_pred))
# Out:
# 模型准确率: 0.9650972333899163
# 分类报告:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97     17908
#            1       0.95      0.97      0.96     15671
#
#     accuracy                           0.97     33579
#    macro avg       0.96      0.97      0.96     33579
# weighted avg       0.97      0.97      0.97     33579

# %%
# 生成x轴的取值，可以是样本索引
x = np.arange(50)
plt.figure(figsize=(10, 4))
# 绘制预测值和真实值的关系图
plt.plot(x, y_pred[:50], label='Predicted', marker='s', linestyle='', color = 'c')
plt.plot(x, y_test[:50], label='True', marker='x', linestyle='', color = 'r')

# 添加标签和标题
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('Comparison between Predicted and True Values')

# 添加网格线
plt.grid(True)

# 添加图例
plt.legend()

# 显示图像
plt.show()

x = np.arange(50)
plt.figure(figsize=(10, 4))
plt.plot(x, y_pred[4000:4050], label='Predicted', marker='s', linestyle='', color = 'c')
plt.plot(x, y_test[4000:4050], label='True', marker='x', linestyle='', color = 'r')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('Comparison between Predicted and True Values')
plt.grid(True)
plt.legend()
plt.show()

# %%
print(model.coef_)
# Out:
# [[ 4.31699782e-02  7.52532084e-02  1.77027197e+01 -6.15005934e-05
#    1.97896601e+00  5.63191047e+00]]

# %%
plt.rcParams['axes.unicode_minus'] = False

coef = pd.Series(model.coef_.flatten(), index = X_test.columns, name = 'Var')
plt.figure(figsize=(8, 5))
coef.sort_values().plot(kind='barh')
plt.title('Variances Importances')
# Out:
# Text(0.5, 1.0, 'Variances Importances')

# %%
type(X)
X = pd.DataFrame(X)
X_np = X_test.to_numpy()
y_np = np.array([0.04, 0.075, 17, 0.000012, 2, 5.6])
print(y_np)
# Out:
# [4.0e-02 7.5e-02 1.7e+01 1.2e-05 2.0e+00 5.6e+00]

# %%
import numpy as np

def sigmoid(z):
    """Sigmoid 函数"""
    return 1 / (1 + np.exp(-z))

def logistic_regression(X, beta):
    """逻辑回归模型"""
    z = np.dot(X, beta)
    return sigmoid(z)

# 计算预测概率
predictions = logistic_regression(X_np, y_np)
print("Predictions:", predictions)
# Out:
# Predictions: [1.        0.9980362 1.        ... 1.        1.        1.       ]

# %%
y = pd.DataFrame(predictions)
y = y.sort_values(by=0)
y_2 = X_test
x = list(range(len(y)))
fun_df = pd.concat([pd.DataFrame(x), y], axis=1)
plt.scatter(x ,y, s=1)
plt.title('Fitting Function')
plt.xlabel('index')
plt.ylabel('predict y')
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred.round())
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import statsmodels.api as sm


X = data[['distance_from_home', 'distance_from_last_transaction', 'online_order', 
         'transaction_amount', 'ratio_to_median_purchase_price', 'days_since_last_transaction_category']]
y = data['fraud']


# 创建逻辑回归模型
logit_model = sm.Logit(y, X)

# 拟合模型
result = logit_model.fit()

# 打印模型摘要
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.328901
#          Iterations 8
#                            Logit Regression Results
# ...
# Dep. Variable:                  fraud   No. Observations:               167894
# Model:                          Logit   Df Residuals:                   167888
# Method:                           MLE   Df Model:                            5
# Date:                Sat, 20 Apr 2024   Pseudo R-squ.:                  0.5237
# Time:                        15:48:44   Log-Likelihood:                -55220.
# converged:                       True   LL-Null:                   -1.1594e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
plt.rcParams['axes.unicode_minus'] = False

coef = pd.Series([0.02, 0.03, -0.6, 0.00002, 1.05, -3.03], index = X_test.columns, name = 'Var')
plt.figure(figsize=(8, 5))
coef.sort_values().plot(kind='barh')
plt.title('Variances Parameters')
# Out:
# Text(0.5, 1.0, 'Variances Importances')

# %%
import numpy as np

def sigmoid(z):
    """Sigmoid 函数"""
    return 1 / (1 + np.exp(-z))

def logistic_regression(X, beta):
    """逻辑回归模型"""
    z = np.dot(X, beta)
    return sigmoid(z)


X = pd.DataFrame(X)
X_np = X_test.to_numpy()
y_np = np.array([0.02, 0.03, -0.6, 0.00002, 1.05, -3.03])

# 计算预测概率
predictions = logistic_regression(X_np, y_np)
print("Predictions:", predictions)
y = pd.DataFrame(predictions)
y = y.sort_values(by=0)
y_2 = X_test
x = list(range(len(y)))
fun_df = pd.concat([pd.DataFrame(x), y], axis=1)
plt.scatter(x ,y , s=1)
plt.title('Fitting Function')
plt.xlabel('index')
plt.ylabel('predict y')
plt.show()
# Out:
# Predictions: [0.99989556 0.97388945 0.47251685 ... 0.17450058 0.9850102  0.0875953 ]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# 分离特征和目标
X = data.drop('fraud', axis=1)
y = data['fraud']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)


# 创建线性回归模型
model = LinearRegression()

# 训练模型
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)

# 在测试集上进行预测
y_test_pred = model.predict(X_test)

# 计算均方误差
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Train MSE:", train_mse)
print("Test MSE:", test_mse)


y_pred = np.where(y_test_pred < 0.45, 0, 1)
accuracy = accuracy_score(y_test, y_pred)
print("模型准确率:", accuracy)
x = np.arange(50)
plt.figure(figsize=(10, 4))
plt.plot(x, y_pred[4000:4050], label='Predicted', marker='s', linestyle='', color = 'c')
plt.plot(x, y_test[4000:4050], label='True', marker='x', linestyle='', color = 'r')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('Comparison between Predicted and True Values')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Train MSE: 0.13327619692441722
# Test MSE: 0.1309304437006465
# 模型准确率: 0.9562226391494684

# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np


# 创建决策树分类器
model = DecisionTreeClassifier()

# 拟合模型
model.fit(X, y)

print(model.feature_importances_)
# Out:
# [2.34462519e-01 8.92135575e-02 5.06978542e-02 9.33633909e-03
#  6.15676197e-01 6.13533206e-04]

# %%
pip install tensorflow keras matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/e4/14/d795bb156f8cc10eb1dcfe1332b7dbb8405b634688980aa9be8f885cc888/tensorflow-2.16.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for keras from https://files.pythonhosted.org/packages/48/a6/ac5cc97a2677e07d3ac359d05cfb2974ec16c8c8ae6dd265e94706256608/keras-3.2.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.16.1 from https://files.pythonhosted.org/packages/e0/36/6278e4e7e69a90c00e0f82944d8f2713dd85a69d1add455d9e50446837ab/tensorflow_intel-2.16.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix
import pandas as pd
import graphviz


# 分离特征和目标
X = data.drop('fraud', axis=1)
y = data['fraud']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# 创建决策树模型
model = DecisionTreeClassifier(max_depth = 5, random_state=19)

# 训练模型
model.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = model.predict(X_test)

# 计算准确率
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# 可视化决策树
plt.figure(figsize=(100,20))
plot_tree(model, feature_names=X.columns, class_names=["Not Fraud", "Fraud"], filled=True, rounded=True, fontsize = 15)
plt.show()

# 可视化混淆矩阵
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Accuracy: 0.9889216474582329

# %%
pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Obtaining dependency information for graphviz from https://files.pythonhosted.org/packages/00/be/d59db2d1d52697c6adc9eacaf50e8965b6345cc143f671e1ed068818d5cf/graphviz-0.20.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ---------------------------------- ----- 41.0/47.1 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 47.1/47.1 kB 466.9 kB/s eta 0:00:00
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix


# 分离特征和目标
X = data.drop('fraud', axis=1)
y = data['fraud']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# 创建随机森林模型
model = RandomForestClassifier(max_depth = 4, n_estimators=100, random_state=17)

# 训练模型
model.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = model.predict(X_test)

# 计算准确率
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# 绘制特征重要性
plt.figure(figsize=(10, 6))
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]
plt.bar(range(X.shape[1]), importances[indices], color='skyblue')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Variable parameters')
plt.show()

# 可视化混淆矩阵
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Accuracy: 0.987879329342744
